# %%
import pandas as pd

# %%
#데이터 로딩
orders_df = pd.read_csv('../data/orders.csv')
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        200000 non-null  int64
#  1   customer_id     200000 non-null  int64
#  2   order_datetime  198067 non-null  str
#  3   channel         200000 non-null  str
#  4   status          200000 non-null  str
# dtypes: int64(2), str(3)
# memory usage: 13.4 MB

# %%
con1 = orders_df['channel']=='web'
con2 = orders_df['status']=='delivered'
seq = orders_df[con1&con2]
seq.shape[0] #web으로 주문되고 배송완료된건 60455개이다
# Out:
# 60455

# %%
sql_condition='channel=="web" and status=="delivered"'
seqq = orders_df.query(sql_condition)
seqq.shape[0] #위로 똑같은 결과지만 query문 사용함.
# Out:
# 60455

# %%
#직접해보기

# %%
#여러 조건을 자유롭게 조합
#주문 경로'web', 주문상태가 '배송완료', 6월 주문
con1 = orders_df['channel']=='web'
con2 = orders_df['status']=='delivered'
con3 = orders_df['order_datetime'].dt.month == 6

seq3 = orders_df[
    con1&con2&con3
]

seq3.shape[0] #행수 -> which is 건수 = 13077
# Out:
# 13077

# %%
orders_df.head()
# Out:
#    order_id  customer_id       order_datetime channel     status
# 0     25463         1077  2024-06-25 00:17:41   store  delivered
# 1    171088         2998  2024-05-28 19:35:20     web  delivered
# 2     27437         4066  2024-02-14 17:49:14     app  delivered
# 3     98425         3243  2024-05-08 16:37:36   store  delivered
# 4     22325         5331  2024-04-17 20:08:22     app  delivered

# %%
orders_df['order_datetime'][1].split('-')[1] == '06'
#6월찾기 -> 월을 잘라내야됨 split
# Out:
# True

# %%
orders_df.info()
orders_df = pd.read_csv('../data/orders.csv', parse_dates=['order_datetime'])
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        200000 non-null  int64
#  1   customer_id     200000 non-null  int64
#  2   order_datetime  198067 non-null  str
#  3   channel         200000 non-null  str
#  4   status          200000 non-null  str
# dtypes: int64(2), str(3)
# memory usage: 13.4 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        200000 non-null  int64
#  1   customer_id     200000 non-null  int64
#  2   order_datetime  198067 non-null  datetime64[us]
#  3   channel         200000 non-null  str
#  4   status          200000 non-null  str
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 9.7 MB

# %%
orders_df['order_datetime'].dt.month == 6
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 199995    False
# 199996    False
# 199997    False
# 199998    False
# 199999    False
# Name: order_datetime, Length: 200000, dtype: bool
