# %%
import pandas as pd

customers_df = pd.read_csv('../data/customers.csv')

# %%
#고객번호 중복 확인
customers_df['customer_id'].duplicated().sum()   #중복 여부 (True/False)
customers_df['customer_id'].duplicated().sum()
# Out:
# np.int64(50)

# %%
#중복된 고객정보를 추출
dup_cust = customers_df[
    customers_df['customer_id'].duplicated()
]

dup_cust
# Out:
#       customer_id name gender  birth_date signup_date city  \
# 795          3002  윤선우    NaN  1968-06-30  2023-06-15   부산
# 827          1683  홍준예      여  1978-01-02  2024-01-31   고양
# 1092         5741  임은민      남  2004-04-24  2023-07-31   서울
# 1420         1389  최도은      여  1982-05-11  2020-02-05   인천
# 1525         2682  김현지      남  1982-05-23  2023-05-15  대구
# 1655         1438  이도아      남  1957-07-20  2022-08-12   대전
# 2174         3018  권성은      M  1969-11-18  2022-12-29   울산
# 2211         3136  한예성      M  1970-11-11  2020-06-12   수원
# 2218         1704  박우연      M  1962-01-16  2021-01-04   대구
# 2407         2675  홍성선    NaN  1990-11-16  2021-04-27   부산
# 2436         1975  정지우      F  1997-02-04  2024-03-14   울산
# 2505         2856  윤도민      여  1985-06-17  2024-06-28   서울
# 2514         2768  이현수      M  1959-02-22  2024-03-03   고양
# 2657         5700  송준우      F  1961-09-07  2022-01-31   부산
# 2754         5290  이준민      여  2000-02-16  2020-02-03   고양
# ...
